# %%
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# %%
fp = Path("crypto_data.csv")
df = pd.read_csv(fp)
df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %%
crypto_istrading = df.loc[df["IsTrading"] == True]
crypto_istrading
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1243              NaN      1000000000
# 1244              NaN      1000000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [1144 rows x 7 columns]

# %%
crypto_df = crypto_istrading.drop(columns=['IsTrading'], axis=1)

# %%
for column in crypto_df.columns:
    print(f"Column {column} has {crypto_df[column].isnull().sum()} null values")
# Out:
# Column Unnamed: 0 has 0 null values
# Column CoinName has 0 null values
# Column Algorithm has 0 null values
# Column ProofType has 0 null values
# Column TotalCoinsMined has 459 null values
# Column TotalCoinSupply has 0 null values

# %%
no_null = crypto_df.dropna(how='any')

# %%
for column in no_null.columns:
    print(f"Column {column} has {no_null[column].isnull().sum()} null values")
# Out:
# Column Unnamed: 0 has 0 null values
# Column CoinName has 0 null values
# Column Algorithm has 0 null values
# Column ProofType has 0 null values
# Column TotalCoinsMined has 0 null values
# Column TotalCoinSupply has 0 null values

# %%
# Find duplicate entries
print(f"Duplicate entries: {no_null.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
mined_coins_df = no_null.loc[no_null['TotalCoinsMined'] > 0]
mined_coins_df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC    Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH   Ethereum    Ethash       PoW     1.076842e+08               0

# %%
ml_df = mined_coins_df.drop(columns=["CoinName", "Unnamed: 0"])
# ml_df = drop_name.rename(columns={"Unnamed: 0": "crypto_symbol"})
ml_df

# df.rename(columns={"A": "a", "B": "c"})
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1238      SHA-256      DPoS     2.000000e+09      2000000000
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
#
# [532 rows x 4 columns]

# %%
cryp_dummies = pd.get_dummies(ml_df)

# %%
cryp_dummies.shape
# Out:
# (532, 377)

# %%
# Scaling the X data by using StandardScaler()
scaler = StandardScaler().fit(cryp_dummies)
crypto_scaled = scaler.transform(cryp_dummies)
crypto_scaled
# Out:
# array([[-0.11710817, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.09396955, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [ 0.52494561, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        ...,
#        [-0.09561336, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11694817, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ],
#        [-0.11710536, -0.0433963 , -0.0433963 , ..., -0.0433963 ,
#         -0.0433963 , -0.0433963 ]])

# %%
# Applying PCA to reduce dimensions from 4 to 2

# Initialize PCA model
pca = PCA(n_components = .9, svd_solver='full')

# Get principal components for the crypto data.
crypto_pca = pca.fit_transform(crypto_scaled)

crypto_pca
# Out:
# array([[-2.67092248e-01, -1.16293969e-01, -4.07308196e-15, ...,
#         -2.23119616e+00,  8.51753867e-01, -8.58553139e-01],
#        [-2.49924699e-01, -1.17272732e-01, -3.24189932e-15, ...,
#          5.38325025e-01, -8.55610849e-01, -1.97673497e-02],
#        [ 3.14746498e-01, -2.86187718e-03, -1.21232852e-14, ...,
#          9.85168494e-01,  4.74366202e-01,  8.77559983e-01],
#        ...,
#        [-6.67192566e-02, -3.11211774e-01,  3.94946004e-15, ...,
#         -9.78312586e-01,  3.56291295e-01, -9.25294434e-01],
#        [-2.90507995e-01, -2.45950491e-01,  3.90732370e-15, ...,
#         -1.49684155e-15,  3.04374468e-15, -1.96241433e-15],
#        -1.47603166e+00,  1.11440601e+01,  7.04454374e+00,  1.69580765e+01,
#        -7.25608730e+00,  3.75142360e+00,  8.64575863e+00,  5.82513952e+00,
#        -1.32661619e+01,  1.62890804e+00, -1.60306377e+01,  7.24160767e+00,
#        -1.03327665e+01,  9.47998524e+00, -9.26669884e+00, -1.54311872e+00,
#        -1.02669334e+01, -1.04058027e+01,  8.16617870e+00,  1.71669273e+01,
#        -2.18886395e+01, -1.22186003e+01,  5.40873528e-01, -4.99445963e+00,
#        -1.63060760e+01,  1.30767288e+01, -2.54291153e+00, -7.95890629e-01,
#         1.34490108e+01,  8.87826443e-01, -4.14905220e-01,  6.66369021e-01,
#         1.71464577e+01,  8.91562641e-01, -1.29971668e-01, -4.42336273e+00,
#         2.67377114e+00, -2.97681063e-01,  5.91248131e+00, -1.00434561e+01,
#        -2.36049709e+01, -1.10129843e+01,  2.86971331e+00,  5.13829470e+00,
#        -6.97895718e+00, -1.29883986e+01,  1.11994112e+00,  1.31149645e+01,
#        -8.22693729e+00, -7.00937939e+00,  1.32083893e+01, -5.79885864e+00,
#         3.14333701e+00, -1.07848082e+01,  1.88800163e+01, -4.90742064e+00,
#         7.31848907e+00, -2.65534878e-01,  8.13708496e+00, -1.22301922e+01,
#        -6.99653168e+01, -2.13289852e+01,  5.40558434e+00,  6.22192612e+01,
#        -1.82532692e+01, -2.73121905e+00,  5.11221504e+00,  7.44934738e-01,
#         5.41525269e+00,  2.06434846e+00, -8.70724392e+00, -2.56733274e+00,
#         2.38739896e+00,  1.71669273e+01,  7.24501991e+00, -1.37234364e+01,
#        -1.92697334e+01,  2.12027988e+01, -4.34023523e+00, -9.96001053e+00,
#         9.30125332e+00, -1.61701145e+01, -6.63822937e+00,  5.30455303e+00,
#        -1.59490168e+00, -5.97388220e+00, -2.45714855e+00,  2.07491436e+01,
#        -3.26973891e+00, -5.51907969e+00, -3.23210931e+00,  7.22897959e+00,
#        -3.13707304e+00,  1.82923698e+01, -8.13072777e+00, -4.14601231e+00,
#         1.18011255e+01, -1.39465876e+01, -1.21168423e+01, -2.44758282e+01,
#         6.10312510e+00, -6.86610758e-01,  1.66420498e+01, -1.43009958e+01,
#        -6.11098433e+00,  4.56272697e+00,  5.25750446e+00,  5.38699055e+00,
#        -1.52866955e+01,  7.73110747e-01, -2.01177807e+01,  9.28707790e+00,
#         1.10127258e+01, -7.36410904e+00, -7.14255381e+00, -1.61800556e+01,
#        -6.87007952e+00, -1.61800499e+01, -5.05809784e+00,  2.52036214e+00,
#        -1.27078657e+01, -3.08716464e+00,  7.58336127e-01,  2.22167568e+01,
#         3.88495159e+00,  6.70607615e+00,  4.27103329e+00, -1.75008945e+01],
#       dtype=float32)

# %%
# Prepare to plot the dataset

# The first column of transformed features
crypto_pca['x'] = tsne_features[:,0]

# The second column of transformed features
crypto_pca['y'] = tsne_features[:,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/yg/fw1cq33d4rsfsxc74d4p2mrc0000gn/T/ipykernel_17704/76642674.py in <module>
#       2
#       3 # The first column of transformed features
# ----> 4 crypto_pca['x'] = tsne_features[:,0]
#       5
#       6 # The second column of transformed features
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
